# %%
print("In this notebook we eill learn about functions")
# Out:
# In this notebook we eill learn about functions

# %% [markdown]
# # Functions
# ## Definition:-
# ### It is a set of block of codes to perform specific task
