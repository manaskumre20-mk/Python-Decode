# %%
print("In this notebook we will learn about functions")
# Out:
# In this notebook we will learn about functions

# %% [markdown]
# # Functions
# ## Definition:-
# ### It is a block of codes to perform specific task

# %%
#defining
#def functionname():
#    block of code
def sum(a,b):
    c=a+b
    print(c)
#calling
#functionname()
sum(10,20)
# Out:
# 30

# %%
n1=int(input("enter any number: "))
n2=int(input("enter any number: "))
sum(n1,n2)
# Out:
# enter any number:  10
# enter any number:  40
# 50

# %%
# 1. without parameter without
